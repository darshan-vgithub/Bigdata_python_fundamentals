# %%
range(5)
# Out:
# range(0, 5)

# %%
for i in range(1,6): # range(start, stop, step)
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,10,2): # range(start, stop, step) here step the last index will excluded
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#strings........
str="Darshan Venkatesh Murthy"

for i in str:
    print(i)
# Out:
# D
# a
# r
# s
# h
# a
# n
#
# V
# e
# n
# k
# a
# t
# e
# s
# h
#
# M
# u
# r
# t
# h
# y
