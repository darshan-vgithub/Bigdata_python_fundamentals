# %%
print("Hello World")
# Out:
# Hello World

# %%
age=18

if age>=18:
    print("you are allowed to vote")
# Out:
# you are allowed to vote

# %%
# if and else
age =16

if age>=18:
    print("you are allowed to vote")
else:
    print("you are minor")
# Out:
# you are minor

# %%
# if else and elif.............................
age =12

if age>=18:
    print("you are allowed to vote")
elif age>=16:
    print("you can drive")
else:
    print("you are minor")
# Out:
# you are minor

# %%
# nested if else statements

# find the number is odd , even , negative or positive

num=int(input("enter the number"))

if(num>=0):
    print("positive number")
    if(num%2==0):
        print("even number")
    else:
        print("odd number")
else:
    print("negative number")
# Out:
# negative number

# %%
# determine the year is a leap year or not

year=int(input("enter the year"))

if(year%4==0):
    if(year%100==0):
        if(year%400==0):
            print("leap year")
        else:
            print("not a leap year")
    else:
        print("leap year")
else:
    print("not a leap year")
# Out:
# leap year

# %%
# Simple calculator program

num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
operator=input("enter the operator")

if(operator=="+"):
    print(num1+num2)
elif(operator=="-"):
    print(num1-num2)
elif(operator=="*"):
    print(num1*num2)
elif(operator=="/"):
    print(num1/num2)
else:
    print("invalid operator")
# Out:
# 4
